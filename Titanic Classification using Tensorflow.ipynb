# %%
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv(r'C:\Users\jayad\Desktop\DATA\Titanic\train.csv')
df_test = pd.read_csv(r'C:\Users\jayad\Desktop\DATA\Titanic\train.csv')

# %%
df_train = df_train.fillna(0)
df_test = df_test.fillna(0)

# %%
df_train = df_train.drop('Name', axis=1)

# %%
df_test = df_test.drop('Name', axis=1)

# %%
df_train = df_train.drop('Ticket', axis=1)
df_test = df_test.drop('Ticket', axis=1)

# %%
df_train.head(10)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    male  22.0      1      0   7.2500     0
# 1            2         1       1  female  38.0      1      0  71.2833   C85
# 2            3         1       3  female  26.0      0      0   7.9250     0
# 3            4         1       1  female  35.0      1      0  53.1000  C123
# 4            5         0       3    male  35.0      0      0   8.0500     0
# 5            6         0       3    male   0.0      0      0   8.4583     0
# 6            7         0       1    male  54.0      0      0  51.8625   E46
# 7            8         0       3    male   2.0      3      1  21.0750     0
# 8            9         1       3  female  27.0      0      2  11.1333     0
# 9           10         1       2  female  14.0      1      0  30.0708     0
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S
# 5        Q
# 6        S
# 7        S
# 8        S
# ...

# %%
from sklearn import preprocessing

# %%
le = sk.preprocessing.LabelEncoder()

# %%
df_train.head(20)
# Out:
#     PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0             1         0       3    male  22.0      1      0   7.2500     0
# 1             2         1       1  female  38.0      1      0  71.2833   C85
# 2             3         1       3  female  26.0      0      0   7.9250     0
# 3             4         1       1  female  35.0      1      0  53.1000  C123
# 4             5         0       3    male  35.0      0      0   8.0500     0
# 5             6         0       3    male   0.0      0      0   8.4583     0
# 6             7         0       1    male  54.0      0      0  51.8625   E46
# 7             8         0       3    male   2.0      3      1  21.0750     0
# 8             9         1       3  female  27.0      0      2  11.1333     0
# 9            10         1       2  female  14.0      1      0  30.0708     0
# 10           11         1       3  female   4.0      1      1  16.7000    G6
# ...

# %%
df_train['Sex'] = le.fit_transform(df_train['Sex'])

# %%
df_train['Embarked'] = le.fit_transform(df_train['Embarked'].astype(str))

# %%
df_test['Sex'] = le.fit_transform(df_test['Sex'])
df_test['Embarked'] = le.fit_transform(df_test['Embarked'].astype(str))

# %%
df_train = df_train.drop('Cabin', axis=1)
df_test = df_test.drop('Cabin', axis=1)
