# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
data =  pd.read_csv(r"C:\Users\jayad\Downloads\Bike-Sharing-Dataset\hour.csv")

# %%
print(data.columns)
# Out:
# Index([u'instant', u'dteday', u'season', u'yr', u'mnth', u'hr', u'holiday',
#        u'weekday', u'workingday', u'weathersit', u'temp', u'atemp', u'hum',
#        u'windspeed', u'casual', u'registered', u'cnt'],
#       dtype='object')

# %%
ind = ['instant', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
       'workingday', 'weathersit',
       'casual', 'registered', 'cnt']

# %%
for i in ind:
    data[i].astype(int)

# %%
pd.to_datetime(data['dteday'])
# Out:
# 0       2011-01-01
# 1       2011-01-01
# 2       2011-01-01
# 3       2011-01-01
# 4       2011-01-01
# 5       2011-01-01
# 6       2011-01-01
# 7       2011-01-01
# 8       2011-01-01
# 9       2011-01-01
# 10      2011-01-01
# 11      2011-01-01
# 12      2011-01-01
# 13      2011-01-01
# 14      2011-01-01
# 15      2011-01-01
# 16      2011-01-01
# 17      2011-01-01
# 18      2011-01-01
# 19      2011-01-01
# 20      2011-01-01
# 21      2011-01-01
# 22      2011-01-01
# 23      2011-01-01
# 24      2011-01-02
# 25      2011-01-02
# 26      2011-01-02
# 27      2011-01-02
# 28      2011-01-02
# 29      2011-01-02
#            ...
# 17349   2012-12-30
# 17350   2012-12-30
# 17351   2012-12-30
# 17352   2012-12-30
# 17353   2012-12-30
# 17354   2012-12-30
# 17355   2012-12-31
# 17356   2012-12-31
# 17357   2012-12-31
# 17358   2012-12-31
# 17359   2012-12-31
# 17360   2012-12-31
# 17361   2012-12-31
# 17362   2012-12-31
# 17363   2012-12-31
# 17364   2012-12-31
# ...

# %%
float_ind = ['temp', 'atemp', 'hum', 'windspeed']

# %%
for i in float_ind:
    data[i].astype(float)

# %%
print(data.dtypes)
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
data = data.drop('casual', axis = 1).drop('registered', axis = 1).drop('yr', axis=1).drop('mnth', axis =1)

# %%
data.columns
# Out:
# Index([u'instant', u'dteday', u'season', u'hr', u'holiday', u'weekday',
#        u'workingday', u'weathersit', u'temp', u'atemp', u'hum', u'windspeed',
#        u'cnt'],
#       dtype='object')

# %%
data_train = data[:12000]
data_test = data[12000:]

# %%
data_set_test = data_test.drop('cnt', axis = 1).drop('dteday', axis = 1)

# %%
data_set_test.columns
# Out:
# Index([u'instant', u'season', u'hr', u'holiday', u'weekday', u'workingday',
#        u'weathersit', u'temp', u'atemp', u'hum', u'windspeed'],
#       dtype='object')

# %%
data_train.columns
# Out:
# Index([u'instant', u'dteday', u'season', u'hr', u'holiday', u'weekday',
#        u'workingday', u'weathersit', u'temp', u'atemp', u'hum', u'windspeed',
#        u'cnt'],
#       dtype='object')

# %%
data_train.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# cnt             int64
# dtype: object

# %%
data_train_label = data_train['cnt']

# %%
model = LinearRegression()
data_list_train = list()

# %%
data_train = data_train.drop('cnt', axis = 1).drop('dteday', axis = 1)

# %%
data_list_train = map(list, data_train.values)

# %%
data_list_train
# Out:
# [[1.0, 1.0, 0.0, 0.0, 6.0, 0.0, 1.0, 0.24, 0.2879, 0.81, 0.0],
#  [2.0, 1.0, 1.0, 0.0, 6.0, 0.0, 1.0, 0.22, 0.2727, 0.8, 0.0],
#  [3.0, 1.0, 2.0, 0.0, 6.0, 0.0, 1.0, 0.22, 0.2727, 0.8, 0.0],
#  [4.0, 1.0, 3.0, 0.0, 6.0, 0.0, 1.0, 0.24, 0.2879, 0.75, 0.0],
#  [5.0, 1.0, 4.0, 0.0, 6.0, 0.0, 1.0, 0.24, 0.2879, 0.75, 0.0],
#  [6.0, 1.0, 5.0, 0.0, 6.0, 0.0, 2.0, 0.24, 0.2576, 0.75, 0.0896],
#  [7.0, 1.0, 6.0, 0.0, 6.0, 0.0, 1.0, 0.22, 0.2727, 0.8, 0.0],
#  [8.0, 1.0, 7.0, 0.0, 6.0, 0.0, 1.0, 0.2, 0.2576, 0.86, 0.0],
#  [9.0, 1.0, 8.0, 0.0, 6.0, 0.0, 1.0, 0.24, 0.2879, 0.75, 0.0],
#  [10.0, 1.0, 9.0, 0.0, 6.0, 0.0, 1.0, 0.32, 0.3485, 0.76, 0.0],
#  [11.0, 1.0, 10.0, 0.0, 6.0, 0.0, 1.0, 0.38, 0.3939, 0.76, 0.2537],
#  [12.0, 1.0, 11.0, 0.0, 6.0, 0.0, 1.0, 0.36, 0.3333, 0.81, 0.2836],
#  [13.0, 1.0, 12.0, 0.0, 6.0, 0.0, 1.0, 0.42, 0.4242, 0.77, 0.2836],
#  [14.0, 1.0, 13.0, 0.0, 6.0, 0.0, 2.0, 0.46, 0.4545, 0.72, 0.2985],
#  [15.0, 1.0, 14.0, 0.0, 6.0, 0.0, 2.0, 0.46, 0.4545, 0.72, 0.2836],
# ...

# %%
data_train.columns
# Out:
# Index([u'instant', u'season', u'hr', u'holiday', u'weekday', u'workingday',
#        u'weathersit', u'temp', u'atemp', u'hum', u'windspeed'],
#       dtype='object')

# %%
model.fit(data_list_train, data_train_label)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
out = model.predict(data_set_test)

# %%
out
# Out:
# array([167.05092757, 188.0763479 , 193.04712613, ..., 274.03852898,
#        289.82138158, 282.40005373])

# %%
print(out)
# Out:
# [167.858356   188.45541876 193.61291285 ... 219.57173857 235.32745762
#  228.37284008]

# %%
len(out)
# Out:
# 5379

# %%
print(data_test['cnt'])
# Out:
# 12000      8
# 12001     25
# 12002     90
# 12003    171
# 12004    313
# 12005    432
# 12006    581
# 12007    637
# 12008    607
# 12009    543
# 12010    502
# 12011    577
# 12012    549
# 12013    474
# 12014    402
# 12015    274
# 12016    233
# 12017    145
# 12018     86
# 12019     40
# 12020     15
# 12021     11
# 12022      2
# 12023      7
# 12024     15
# 12025     79
# 12026    153
# 12027    270
# 12028    186
# 12029     99
#         ...
# 17349    125
# 17350    102
# 17351     72
# 17352     47
# 17353     36
# 17354     49
# 17355     34
# 17356     19
# 17357     11
# 17358      1
# 17359      3
# 17360      9
# 17361     40
# 17362     85
# 17363    196
# 17364    157
# 17365    120
# 17366    157
# 17367    224
# 17368    203
# 17369    247
# 17370    315
# 17371    214
# 17372    164
# 17373    122
# 17374    119
# 17375     89
# 17376     90
# 17377     61
# 17378     49
# Name: cnt, Length: 5379, dtype: int64

# %%
print(r2_score(out, data_test['cnt']))
# Out:
# -4.2222505875414225

# %%
print(mean_squared_error(out, data_test['cnt']))
# Out:
# 33868.331446486336
